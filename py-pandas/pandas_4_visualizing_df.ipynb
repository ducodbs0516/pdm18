# %% [markdown]
# <a href="https://colab.research.google.com/github/ducodbs0516/pdm18/blob/main/py-pandas/pandas_4_visualizing_df.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Python module 3. **pandas**

# %% [markdown]
# # Using pandas

# %% [markdown]
# * [10 Minutes to pandas](https://pandas.pydata.org/pandas-docs/stable/10min.html)
# * [Pandas tutorial with interactive exercises](https://www.kaggle.com/pistak/pandas-tutorial-with-interactive-exercises)

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline  # work for Jupyter notebook or lab

# %%
# Creating a DataFrame by passing a NumPy array, with a datetime index and labeled columns:
dates = pd.date_range('20210927', periods=6)
dates
# Out:
# DatetimeIndex(['2021-09-27', '2021-09-28', '2021-09-29', '2021-09-30',
#                '2021-10-01', '2021-10-02'],
#               dtype='datetime64[ns]', freq='D')

# %%
# head()
df = pd.DataFrame(np.random.randn(6,4), index=dates, columns=list('ABCD'))
df
# Out:
#                    A         B         C         D
# 2021-09-27  0.183567  0.644964  0.172086 -1.443827
# 2021-09-28  0.082703  0.324738  0.958478 -0.639707
# 2021-09-29 -0.778958  0.663144 -0.189937  1.920769
# 2021-09-30  1.612925 -0.159968 -0.687015 -0.900497
# 2021-10-01  0.645610  1.792843  1.537081  1.867407
# 2021-10-02 -0.136576 -0.211774  1.825048  0.367142

# %% [markdown]
# ---

# %% [markdown]
# # 데이터 시각화

# %% [markdown]
# #### [도전] 데이터프레임 df의 평균(mean(0))과 표준편차를 이용한 그래프
# - 평균에 대한 꺽은선그래프
# - 평균과 표준편차를 이용한 막대그래프
# > x-축은 A,B,C,D

# %%
# df의 평균(mean(0))과 표준편차를 이용한 바그래프
bar_labels = df.columns
# plot bars
plt.bar(bar_labels, df.mean(0), yerr=df.std(0), color='rgbcy')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: MatplotlibDeprecationWarning: Using a string of single character colors as a color sequence is deprecated. Use an explicit list instead.
#   after removing the cwd from sys.path.

# %% [markdown]
# ***

# %% [markdown]
# ## pandas의 데이터 시각화 (Visualization)

# %%
df  # 6일 동안의 4개의 항목을 가진 데이터 프레임
# Out:
#                    A         B         C         D
# 2021-09-27  0.183567  0.644964  0.172086 -1.443827
# 2021-09-28  0.082703  0.324738  0.958478 -0.639707
# 2021-09-29 -0.778958  0.663144 -0.189937  1.920769
# 2021-09-30  1.612925 -0.159968 -0.687015 -0.900497
# 2021-10-01  0.645610  1.792843  1.537081  1.867407
# 2021-10-02 -0.136576 -0.211774  1.825048  0.367142

# %% [markdown]
# ### 꺽은선 그래프

# %%
df['A'].plot(marker='o', c='r', ms=8)

# %%
df['C'].plot(marker='D', c='g', ms=8)  # set figsize

# %%
df.plot(y='D', marker='*', c='r', ms=12)   # x-축은 날짜인덱스

# %%
# 두 개의 그래프를 한 축에 그리기
# df['A','D'].plot(marker='o', c='r', ms=8)   # KeyError: ('A', 'D') 
df[['A','D']].plot(marker='o', color='rg', ms=8)  # works!, change colors

# %%
df.plot(y=['A','C'], marker='o')

# %% [markdown]
# ### 산포도 (Scatter graph)

# %%
df
# Out:
#                    A         B         C         D
# 2021-09-27  0.183567  0.644964  0.172086 -1.443827
# 2021-09-28  0.082703  0.324738  0.958478 -0.639707
# 2021-09-29 -0.778958  0.663144 -0.189937  1.920769
# 2021-09-30  1.612925 -0.159968 -0.687015 -0.900497
# 2021-10-01  0.645610  1.792843  1.537081  1.867407
# 2021-10-02 -0.136576 -0.211774  1.825048  0.367142

# %%
df.plot(kind='scatter',x='C',y='A', color='r', marker='o', s=32)

# %%
df.plot(kind='scatter',x='B',y='C', color='blue', marker='d', s=50)

# %% [markdown]
# ### 바 그래프

# %%
df['A'].plot.bar()

# %%
df['D'].plot.bar()

# %%
df.plot(kind='bar', y='D', rot=55)

# %% [markdown]
# #### 다중 바그래프

# %%
df.plot(kind='bar',y=['A','C','D'])

# %% [markdown]
# #### 평균/표준편차 그래프

# %%
df.mean(0), df.std(0), df.columns
# Out:
# (A    0.268212
#  B    0.508991
#  C    0.602624
#  D    0.195214
#  dtype: float64, A    0.806558
#  B    0.733687
#  C    0.997080
#  D    1.441351
#  dtype: float64, Index(['A', 'B', 'C', 'D'], dtype='object'))

# %%
# plot bars
# bar_labels = df.columns
# plt.bar(bar_labels, df.mean(0), yerr=df.std(0))
df.mean(0).plot.bar(yerr=df.std(0), rot=0)   # yerr --> 표준편차, rot=0 --> x축 A,B,C,D 방향

# %% [markdown]
# ---

# %% [markdown]
# ### 그래프 이어 그리기

# %%
x1 = np.arange(0.0, 5.0, 0.01)
y1 = np.sin(2*np.pi*x1)
plt.figure(figsize=(10,4)) # 가로 10, 세로 4
plt.plot(x1, y1, 'o', ms = 4)

# %%
x1.shape, y1.shape  # x1, y1 데이터 개수가 같음
# Out:
# ((500,), (500,))

# %% [markdown]
# #### pandas 데이터프레임을 이용한 그래프

# %%
df = pd.DataFrame(dict(sine=y1), index=x1, columns=['sine'])
df.head()
# Out:
#           sine
# 0.00  0.000000
# 0.01  0.062791
# 0.02  0.125333
# 0.03  0.187381
# 0.04  0.248690

# %%
df.tail()
# Out:
#           sine
# 4.95 -0.309017
# 4.96 -0.248690
# 4.97 -0.187381
# 4.98 -0.125333
# 4.99 -0.062791

# %%
len(df)
# Out:
# 500

# %%
pre_size = int(len(df) * 0.8)
post_size = len(df) - pre_size
pre, post = df.iloc[0:pre_size], df.iloc[pre_size:len(df)] # ML train data, test data 설정
print(len(pre), len(post))
# Out:
# 400 100

# %%
post.shape # test data 20%
# Out:
# (100, 1)

# %%
post2 = post + np.random.normal(scale=0.2, size=len(post)).reshape(-1,1)
'''
size=len(post) --> post 개수 만큼 정규잡음(가우시안 잡음) 생성
reshape(-1,1) --> 무작위 수 100개의 데이터를  numpy array (100,1)으로 생성
scale=0.2 --> 20%의 가우시안 잡음
'''
# Out:
# '\nsize=len(post) --> post 개수 만큼 정규잡음(가우시안 잡음) 생성\nreshape(-1,1) --> 무작위 수 100개의 데이터를  numpy array (100,1)으로 생성\nscale=0.2 --> 20%의 가우시안 잡음\n'

# %%
len(pre),len(post)
# Out:
# (400, 100)

# %%
plt.plot(np.arange(len(pre), len(pre) + len(post)),post2)
# len(pre): 400 부터 len(pre) + len(post): 400+100 까지 그림 --> 정규 잡음(post2) sin 함수 뒷 부분 20% 그래프

# %%
pre
# Out:
#           sine
# 0.00  0.000000
# 0.01  0.062791
# 0.02  0.125333
# 0.03  0.187381
# 0.04  0.248690
# ...        ...
# 3.95 -0.309017
# 3.96 -0.248690
# 3.97 -0.187381
# 3.98 -0.125333
# 3.99 -0.062791
#
# [400 rows x 1 columns]

# %%
plt.figure(figsize=(10,5))
plt.plot(np.arange(0, len(pre)), pre, 'g', label="pre") 
# pre --> np.arange(0, len(pre)): 0부터 400 
plt.plot(np.arange(len(pre), len(pre) + len(post)), post, 'b', marker='.', label="post")
# post --> 잡음이 없는 sin 함수 뒷 부분 20%
plt.plot(np.arange(len(pre), len(pre) + len(post)), post2, 'r', label="post2")
# post2 --> 잡음이 있는 sin 함수 뒷 부분 20% 
plt.ylabel('Value')
plt.xlabel('Time Step')
plt.legend()
plt.show();

# %% [markdown]
# #### post  post2를 동시에 그려서 두 그래프를 비교해보시오.
#
# - subplot 사용

# %%
plt.figure(figsize=(10,5))
plt.subplot(2,1,1).set_title("post")
plt.plot(post, 'y', marker='*')

plt.subplot(2,1,2).set_title("post2")
plt.plot(post2, c ='r')

plt.show()

# %%
fig = plt.figure(figsize=(10,5))
p1 = fig.add_subplot(2,1,1)
p2 = fig.add_subplot(2,1,2)
p1.plot(np.arange(len(pre), len(pre) + len(post)), post, 'b', marker='.')
p2.plot(np.arange(len(pre), len(pre) + len(post)), post2, 'r')

plt.show()

# %% [markdown]
# - subplots 사용

# %%
fig, ax = plt.subplots(2,1, figsize=(10,5))

ax[0].plot(post, c='g')
ax[0].set_ylabel('Value')
ax[0].set_title('No noise')
ax[0].grid()

ax[1].plot(post2, c ='r')
ax[1].set_xlabel('TimeStep')
ax[1].set_ylabel('Value')
ax[1].set_title('Gaussian')
ax[1].grid()

plt.show()

# %%
fig, ax = plt.subplots(2,1, figsize=(10,5))
ax[0].plot(np.arange(len(pre), len(pre) + len(post)), post, c='b')
ax[1].plot(np.arange(len(pre), len(pre) + len(post)), post2, c='r')

plt.show()
